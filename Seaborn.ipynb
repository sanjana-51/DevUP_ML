# %%
import seaborn as sns
import pandas as pd

# %%
df=sns.load_dataset("tips") #inside seaborn there is dataset "tips"

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21236\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# 67% correalation b/w bill and tio means tip increases when total bill incereases

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21236\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot:>

# %%
# JointPlot: allows to study the relationship b/w 2 numeric variable

sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
sns.pairplot(df)

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.countplot('sex',data=df) # either x value or y bcoz one axis is count value
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot('day',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.barplot(y='total_bill',x='smoker',data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %% [markdown]
# boxplots are a powerful data visualization tool that can provide valuable insights into the distribution, outliers, skewness, symmetry, and variability

# %%
sns.boxplot('smoker','total_bill',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot(x="total_bill",y="day",hue="smoker",data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>
